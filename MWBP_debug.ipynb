# %%
import matplotlib.pyplot as plt
from astropy import units
from galpy.potential import plotPotentials
# %matplotlib inline
from bar_model import MWBarPotential as MWBP
from template import MiyamotoNagaiPotential as MNP
# Out:
# galpyWarning: A major change in versions > 1.1 is that all galpy.potential functions and methods take the potential as the first argument; previously methods such as evaluatePotentials, evaluateDensities, etc. would be called with (R,z,Pot), now they are called as (Pot,R,z) for greater consistency across the codebase
# galpyWarning: interppotential_c extension module not loaded, because galpy_interppotential_c.cpython-35m-x86_64-linux-gnu.so image was not found

# %%
mwbp = MWBP()
mnp = MNP()

# %%
plotPotentials(mnp)

# %%
plotPotentials(mwbp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-08cf53b9b4c1> in <module>()
# ----> 1 plotPotentials(mwbp)
#       2 plotPotentials(mnp)
#
# /home/annaj/anaconda3/lib/python3.5/site-packages/galpy/potential_src/Potential.py in plotPotentials(Pot, rmin, rmax, nrs, zmin, zmax, nzs, ncontours, savefilename, aspect, justcontours)
#    1921                 for jj in range(nzs):
#    1922                     potRz[ii,jj]= evaluatePotentials(Pot,nu.fabs(Rs[ii]),
# -> 1923                                                      zs[jj],use_physical=False)
#    1924             if not savefilename == None:
#    1925                 print("Writing savefile "+savefilename+" ...")
#
# /home/annaj/anaconda3/lib/python3.5/site-packages/galpy/util/bovy_conversion.py in wrapper(*args, **kwargs)
#     697                 and isinstance(kwargs['zmax'],units.Quantity):
#     698             kwargs['zmax']= kwargs['zmax'].to(units.kpc).value/ro
# --> 699         return method(*args,**kwargs)
#     700     return wrapper
#     701 def physical_conversion_actionAngle(quantity,pop=False):
#
# /home/annaj/anaconda3/lib/python3.5/site-packages/galpy/util/bovy_conversion.py in wrapped(*args, **kwargs)
#     641                     return out*fac
#     642             else:
# --> 643                 return method(*args,**kwargs)
#     644         return wrapped
#     645     return wrapper
#
# /home/annaj/anaconda3/lib/python3.5/site-packages/galpy/potential_src/Potential.py in evaluatePotentials(Pot, R, z, phi, t, dR, dphi)
#    1519
#    1520     """
# -> 1521     return _evaluatePotentials(Pot,R,z,phi=phi,t=t,dR=dR,dphi=dphi)
#    1522
#    1523 def _evaluatePotentials(Pot,R,z,phi=0.,t=0.,dR=0,dphi=0):
#
# /home/annaj/anaconda3/lib/python3.5/site-packages/galpy/potential_src/Potential.py in _evaluatePotentials(Pot, R, z, phi, t, dR, dphi)
#    1529         return sum
#    1530     elif isinstance(Pot,Potential):
# -> 1531         return Pot._call_nodecorator(R,z,phi=phi,t=t,dR=dR,dphi=dphi)
#    1532     else: #pragma: no cover
#    1533         raise PotentialError("Input to 'evaluatePotentials' is neither a Potential-instance or a list of such instances")
#
# /home/annaj/anaconda3/lib/python3.5/site-packages/galpy/potential_src/Potential.py in _call_nodecorator(self, R, z, phi, t, dR, dphi)
#     257         if dR == 0 and dphi == 0:
#     258             try:
# --> 259                 rawOut= self._evaluate(R,z,phi=phi,t=t)
#     260             except AttributeError: #pragma: no cover
#     261                 raise PotentialError("'_evaluate' function not implemented for this potential")
#
# TypeError: _evaluate() got multiple values for argument 'phi'
